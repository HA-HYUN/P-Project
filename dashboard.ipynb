# %%
import hvplot.pandas
import numpy as np
import panel as pn
import pandas as pd
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='96ea21a1-7951-4d09-9c98-5dcbf8c3d270'>
#   <div id="c5e31211-0067-4d59-bdfe-22aa87fbf346" data-root-id="96ea21a1-7951-4d09-9c98-5dcbf8c3d270" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
pn.state.template.logo = "https://github.com/HA-HYUN/P-Project/blob/main/logo_park.png?raw=true"

# %%
# 다크 모드 CSS 추가
dark_mode_css = """
body {
    background-color: #0C1729; /* 배경색 */
    color: #FFFFFF; /* 텍스트 색 */
}
.bk.pn-widget-box {
    background-color: #1E1E1E; /* 위젯 배경 */
    color: #FFFFFF; /* 위젯 텍스트 */
}
"""

# 커스텀 CSS: Google Fonts 적용
custom_font_css = """
@import url('https://fonts.googleapis.com/css?family=Nanum+Gothic:400');

.bk.pn-template-header {
    font-family: 'Nanum Gothic', sans-serif; 
}
body {
    font-family: 'Nanum Gothic', sans-serif; 
}
.bk.pn-widget-box {
    font-family: 'Nanum Gothic', sans-serif; 
}
"""

# # Panel에 커스텀 CSS 적용
pn.extension(raw_css=[dark_mode_css])
# Panel에 커스텀 CSS 적용
pn.extension(raw_css=[custom_font_css])
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='be4fece7-962e-4dee-b16e-7d93868d958f'>
#   <div id="e0bfa0cc-2da3-4178-987b-41e99b22a2d2" data-root-id="be4fece7-962e-4dee-b16e-7d93868d958f" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
pn.extension(raw_css=[])
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='85739c3d-fbf8-4f37-aa04-02f40841aeb0'>
#   <div id="aba95d67-ed56-4eb8-8bc5-5b1fb1a8c3a7" data-root-id="85739c3d-fbf8-4f37-aa04-02f40841aeb0" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
template = pn.template.ReactTemplate(
    title='최적화 경로 설정과 자율주행 스마트 로봇 도입으로 배송효율성 개선dfasdasdf',
    # sidebar=[freq, phase],
    logo = pn.state.template.logo,
    header_background=ACCENT,
    
)


# React 웹 페이지 삽입 (iframe 사용)
template.main[:, :] = pn.pane.HTML(
    """
    <div style="width: 60%; height: 400%; display: flex; flex-direction: column;">
        <div style="padding: 10px; color: white; font-size: 24px;">
            경로 이동 시뮬레이션 hihihidkjafshdkj
        </div>
        <iframe src="https://herojoon.github.io/react-movie-app/#/" 
                style="flex-grow: 1; width: 100%; border: none; margin: 0; padding: 0;">
        </iframe>
    </div>
    """,
    sizing_mode="stretch_both",  # 부모 요소 크기를 iframe에 맞춤
)



template.show();
# Out:
# Launching server at http://localhost:51412

# %%
ACCENT = "#BB2649"
RED = "#D94467"
GREEN = "#5AD534"

# %%
############### 대시보드 생성 함수 ###############
def create_dashboard():
    grid = pn.GridSpec(sizing_mode='scale_both', max_width=1200)
    # grid[0:3, 0:3] = mode_ratio_chart
    # grid[0:3, 3:6] = hourly_count_chart
    # grid[0:3, 6:9] = avg_distance_chart
    # grid[0:3, 9:12] = avg_time_chart
    # grid[3:5, :] = data_table
    # React 웹 페이지 삽입 (iframe 사용)
    grid[0:3, 0:7] = pn.pane.HTML(
    """
    <div style="width: 60%; height: 400%; display: flex; flex-direction: column;">
        <div style="padding: 10px; color: white; font-size: 24px;">
            경로 이동 시뮬레이션
        </div>
        <iframe src="https://herojoon.github.io/react-movie-app/#/" 
                style="width: 100%; border: none; margin: 0; padding: 0;">
        </iframe>
    </div>
    """
    )

    dashboard = pn.template.FastGridTemplate(
        title="무당이 대시보드",
        logo = pn.state.template.logo ,
        accent_base_color=ACCENT,
        header_background=ACCENT,
        prevent_collision=True,
        save_layout=True,
        theme_toggle=False,
        theme='dark',
        main=grid,
    )
    
    

    return dashboard

############### 대시보드 실행 ###############
dashboard = create_dashboard()
# dashboard.servable()
dashboard.show()
# Out:
# Launching server at http://localhost:50945
